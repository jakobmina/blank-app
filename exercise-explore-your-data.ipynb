# %% [markdown]
# **[Machine Learning Course Home Page](https://www.kaggle.com/learn/machine-learning)**
#
# ---

# %% [markdown]
# This exercise will test your ability to read a data file and understand statistics about the data.
#
# In later exercises, you will apply techniques to filter the data, build a machine learning model, and iteratively improve your model.
#
# The course examples use data from Melbourne. To ensure you can apply these techniques on your own, you will have to apply them to a new dataset (with house prices from Iowa).
#
# The exercises use a "notebook" coding environment.  In case you are unfamiliar with notebooks, we have a [90-second intro video](https://www.youtube.com/watch?v=4C2qMnaIKL4).
#
# # Exercises
#
# Run the following cell to set up code-checking, which will verify your work as you go.

# %%
# Set up code checking
from learntools.core import binder
binder.bind(globals())
from learntools.machine_learning.ex2 import *
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# ## Step 1: Loading Data
# Read the Iowa data file into a Pandas DataFrame called `home_data`.

# %%
import pandas as pd
# Path of the file to read
iowa_file_path = '../input/home-data-for-ml-course/train.csv'
# Fill in the line below to read the file into a variable home_data
home_data = pd.read_csv(iowa_file_path)

# You would then inspect the loaded data, for example:
print(home_data.head())
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# Lines below will give you a hint or solution code
# step_1.hint()
# step_1.solution()

# %% [markdown]
# ## Step 2: Review The Data
# Use the command you learned to view summary statistics of the data. Then fill in variables to answer the following questions

# %%
import pandas as pd

# Path of the file to read
iowa_file_path = '../input/home-data-for-ml-course/train.csv'

# Read the file into a variable home_data
home_data = pd.read_csv(iowa_file_path)

# Step 1: Review the first rows of data
print("Primeras filas del dataset:")
print(home_data.head())
print("\n" + "="*50 + "\n")

# Step 2: Review summary statistics
print("Estadísticas resumidas del dataset:")
print(home_data.describe())
print("\n" + "="*50 + "\n")

# Additional useful information
print("Información general del dataset:")
print(home_data.info())
print("\n" + "="*50 + "\n")

# Shape of the dataset
print(f"Dimensiones del dataset: {home_data.shape[0]} filas y {home_data.shape[1]} columnas")
print("\n" + "="*50 + "\n")

# Column names
print("Nombres de las columnas:")
print(home_data.columns.tolist())
print("\n" + "="*50 + "\n")

# Check for missing values
print("Valores faltantes por columna:")
print(home_data.isnull().sum())
# Out:
# Primeras filas del dataset:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
# ...

# %%
# What is the average lot size (rounded to nearest integer)?
import pandas as pd
from learntools.core import binder
binder.bind(globals())
from learntools.machine_learning.ex7 import *

# Path of the file to read
import pandas as pd
y = home_data.SalePrice
# 1. Ruta del archivo (esta es la correcta para esta lección)
iowa_file_path = '../input/home-data-for-ml-course/train.csv'
feature_names = ['LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF', 'FullBath', 'BedroomAbvGr', 'TotRmsAbvGrd']
X = home_data[feature_names]
# 2. Leer el archivo en la variable home_data
home_data = pd.read_csv(iowa_file_path)

# 3. Verificar que cargó (esto hará que el ejercicio te de el "Correct")
print("ENTORNO PREPARADO!")
step_1.check()
# Out:
# WARNING:root:Ignoring repeated attempt to bind to globals
# ENTORNO PREPARADO!
# Check: When you've updated the starter code, `check()` will tell you whether your code is correct. Remember, you must create the following variable: `test_preds`

# %%
# Lo
import pandas as pd

# 1. Ruta del archivo (esta es la correcta para esta lección)
iowa_file_path = '../input/home-data-for-ml-course/train.csv'

# 2. Leer el archivo en la variable home_data
home_data = pd.read_csv(iowa_file_path)

# 3. Verificar que cargó (esto hará que el ejercicio te de el "Correct")
print("ENTORNO PREPARADO!")
step_1.check()
# Out:
# ENTORNO PREPARADO!
# Check: When you've updated the starter code, `check()` will tell you whether your code is correct. Remember, you must create the following variable: `test_preds`

# %%
#step_2.hint()
#step_2.solution()

# %% [markdown]
# ## Think About Your Data
#
# The newest house in your data isn't that new.  A few potential explanations for this:
# 1. They haven't built new houses where this data was collected.
# 1. The data was collected a long time ago. Houses built after the data publication wouldn't show up.
#
# If the reason is explanation #1 above, does that affect your trust in the model you build with this data? What about if it is reason #2?
#
# How could you dig into the data to see which explanation is more plausible?
#
# Check out this **[discussion thread](https://www.kaggle.com/learn-forum/60581)** to see what others think or to add your ideas.
#
# # Keep Going
#
# You are ready for **[Your First Machine Learning Model](https://www.kaggle.com/dansbecker/your-first-machine-learning-model).**

# %% [markdown]
# ---
# **[Machine Learning Course Home Page](https://www.kaggle.com/learn/machine-learning)**
